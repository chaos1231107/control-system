# %% [markdown]
# <a href="https://colab.research.google.com/github/chaos1231107/control-system/blob/main/data_sma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('alt.txt', encoding='UTF-8')
df.columns = ['time', 'raw', 'sma']
df
# Out:
#       time   raw   sma
# 0      104 -0.05  0.03
# 1      166 -0.29 -0.08
# 2      229 -0.12 -0.09
# 3      291  0.10 -0.09
# 4      353 -0.16 -0.12
# ..     ...   ...   ...
# 424  26240 -0.54 -0.43
# 425  26302 -0.48 -0.45
# 426  26363 -0.32 -0.40
# 427  26425 -0.33 -0.42
# 428  26487 -0.38 -0.38
#
# [429 rows x 3 columns]

# %%
plt.plot(df['time'], df['raw'], label='Raw Data')
plt.plot(df['time'], df['sma'], label='SMA Data')
plt.xlabel('Time[ms]')
plt.ylabel('Altitude[m]')
plt.legend()
plt.show()
